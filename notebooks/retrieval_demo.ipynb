# %% [markdown]
# # TurboCell Atlas Retrieval Trace Notebook
# This notebook shows query provenance, candidate-vs-rerank comparison, and final hit tables.

# %%
import pandas as pd
hits = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\top_hits.csv')
cmp = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\candidate_rerank_comparison.csv')
queries = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\query_definitions.csv')
queries
cmp
hits.head(20)

# %%
hits.groupby(['query','method']).head(10)
