# %% [markdown]
# # TurboCell Atlas Wet-Lab Walkthrough
# This notebook is the easiest entry point for wet researchers. It shows what the inputs look like, what the outputs mean, and where to inspect the executed examples.

# %%
import pandas as pd
use_cases = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\wetlab_examples\wetlab_use_cases.csv')
how_to_read = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\wetlab_examples\how_to_read_outputs.csv')
top_hits = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\wetlab_examples\myofibroblast_top10.csv')
use_cases
how_to_read
top_hits

# %% [markdown]
# ## Bring your own data
# 1. Prepare embeddings in `.npy`.
# 2. Prepare metadata with at least `cell_id` and the columns you want to filter on.
# 3. Use `configs/wetlab_metadata_template.csv` as a starting point.
# 4. Construct a query vector from one cell or a centroid of labeled cells.
# 5. Run the CLI or Python API, then inspect the ranked output table.
