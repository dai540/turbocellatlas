# %% [markdown]
# # TurboCell Atlas End-to-End Benchmark Walkthrough
# This notebook follows the full chain from input dataset description through process stages, query definition, benchmark results, and artifacts.

# %%
import pandas as pd
summary = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\benchmark_summary.csv')
data_dict = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\input_data_dictionary.csv')
stages = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\pipeline_stages.csv')
queries = pd.read_csv(r'C:\Users\daiki\Desktop\codex\turbocellatlas\artifacts\real_data_case_study\query_definitions.csv')
data_dict
stages
queries
summary

# %%
summary.pivot(index='method', columns='query', values='recall_at_100_vs_exact')
